# %%
def customer_info():
    '''Name for the order'''
    name = input('Name: ')
    '''Address to deliver to'''
    address = input('Address: ')
    print(name.title()), print(address.title())

# %%
def customer_info():
    '''Name for the order'''
    name = input('Name: ')
    '''Address to deliver to'''
    address = input('Address: ')
    print(name.title()), print(address.title())

def order_type():
    user_input = input('Delivery, Dine in, or Pick-up: ')
    
    if user_input.lower() == 'delivery':
        customer_info()
    elif user_input.lower() == 'dine in':
        '''Name for the dine in order'''
        name = input('Name: ')
        print(f'{name.title()}\'s pizza for dine in!')
    elif user_input.lower() == 'pick-up':
        '''Name for the pick-up order'''
        name = input('Name: ')
        print(f'{name.title()}\'s pizza for pick-up!')
    else:
        print('Not valid order type!')
        order_type()
order_type()

# %%
def customer_info():
    '''Name for the order'''
    name = input('Name: ')
    '''Address to deliver to'''
    address = input('Address: ')
    return name.title(), address
name, address = customer_info()

# %%
def pizza_order():
    prices = [8.99, 12.99, 17.99]
    small = prices[0]
    medium = prices[1]
    large = prices[-1]
    pizza = input('Enter your pizza size: ')
    if pizza == 's':
        return small
    elif pizza == 'm':
        return medium
    elif pizza == 'l':
        return large

list_of_toppings = ['extra cheese', 'mushrooms', 'bell peppers', 'red onions', 'italian sausage','pepperoni', 'olives']

def pizza_price_plus_topping_price():
    pizza_size_price = pizza_order()  # replace 12.99 with your fuction here (replaced)
    which_toppings = input('What toppings would you like? (seperate each by a comma): ').lower()
    for topping in list_of_toppings:
        #Splitting customer's toppings into seperate values and measuring its length of values
        if len(which_toppings.split(", ")) >= 3:
            return pizza_size_price + 4
        # Then adding pizza price to topping price
        elif len(which_toppings.split(", ")) == 2:
              return pizza_size_price + 3
        elif len(which_toppings.split(", ")) == 1:
            return pizza_size_price + 1.5
        else:
            return pizza_size_price
print(pizza_price_plus_topping_price())
#function for delivery name/address
def customer_info():
    '''Name for the order'''
    name = input('Name: ')
    '''Address to deliver to'''
    address = input('Address: ')
    print(name.title()), print(address.title())
#function for what type of order. This will run first and send it to the "customer_info" function if delivery
def order_type():
    user_input = input('Delivery, Dine in, or Pick-up: ')
    
    if user_input.lower() == 'delivery':
        customer_info()
    elif user_input.lower() == 'dine in':
        '''Name for the dine in order'''
        name = input('Name: ')
        print(f'{name.title()}\'s pizza for dine in!')
    elif user_input.lower() == 'pick-up':
        '''Name for the pick-up order'''
        name = input('Name: ')
        print(f'{name.title()}\'s pizza for pick-up!')
    else:
        print('Not valid order type!')
        order_type()
order_type()

def get_payment_selection():
    '''Takes in an input from the customer and turns that input into an integer'''
    payment_option = int(input('Please select 1 = credit card, 2 = cash, 3 = check '))
    if payment_option == 1:
        str(input('please input credit card number: '))
        print('Thank you for your payment, enjoy your delicious pizza!')
    elif payment_option == 2:
        print('please pay at the store, no bills over $50 accepted')
    elif payment_option == 3:
        print('present second id and no orders under $20 accepted when paying by check')
    else:
        print('please enter a selection from 1-3')
get_payment_selection()

# %%
def get_payment_selection():
    '''Takes in an input from the customer and turns that input into an integer'''
    payment_option = int(input('Please select 1 = credit card, 2 = cash, 3 = check '))
    if payment_option == 1:
        str(input('please input credit card number'))
        print('Thank you for your payment, enjoy your delicious pizza!')
    elif payment_option == 2:
        print('please pay at the store, no bills over $50 accepted')
    elif payment_option == 3:
        print('present second id and no orders under $20 accepted when paying by check')
    else:
        print('please enter a selection from 1-3')
get_payment_selection()

# %%
list_of_toppings = ['extra cheese', 'mushrooms', 'bell peppers', 'red onions', 'italian sausage','pepperoni', 'olives']

def pizza_price_plus_topping_price():
    which_toppings = input('What toppings would you like? (seperate each by a comma): ').lower()
    pizza_size_price = pizza_order()  # replace 12.99 with your fuction here (replaced)
    for topping in list_of_toppings:
        #Splitting customer's toppings into seperate values and measuring its length of values
        if len(which_toppings.split(", ")) >= 3:
            return pizza_size_price + 4
        # Then adding pizza price to topping price
        elif len(which_toppings.split(", ")) == 2:
              return pizza_size_price + 3
        elif len(which_toppings.split(", ")) == 1:
            return pizza_size_price + 1.5
        else:
            return pizza_size_price
pizza_price_plus_topping_price()

# %%
def get_payment_selection():
    payment_option = int(input('Please select 1 = credit card, 2 = cash, 3 = check '))
    if payment_option == 1:
        print('please input credit card number')
    elif payment_option == 2:
        print('please pay at the store, no bills over $50 accepted')
    elif payment_option == 3:
        print('present second id and no orders under $20 accepted when paying by check')
    else:
        print('please enter a selection from 1-3')
get_payment_selection()

# %%
def pizza_order():
    prices = [8.99, 12.99, 17.99]
    small = prices[0]
    medium = prices[1]
    large = prices[-1]
    pizza = input('Enter your pizza size: ')
    if pizza == 's':
        return small
    elif pizza == 'm':
        return medium
    elif pizza == 'l':
        return large

list_of_toppings = ['extra cheese', 'mushrooms', 'bell peppers', 'red onions', 'italian sausage','pepperoni', 'olives']

def pizza_price_plus_topping_price():
    which_toppings = input('What toppings would you like?: ').lower()
    pizza_size_price = pizza_order()  # replace 12.99 with your fuction here (replaced)
    for topping in list_of_toppings:
        #Splitting customer's toppings into seperate values and measuring its length of values
        if topping >= 3:
            return pizza_size_price + 4
        # Then adding pizza price to topping price
        elif topping == 2:
              return pizza_size_price + 3
        elif topping == 1:
            return pizza_size_price + 1.5
        else:
            return pizza_size_price
print(pizza_price_plus_topping_price())
#function for delivery name/address
def customer_info():
    '''Name for the order'''
    name = input('Name: ')
    '''Address to deliver to'''
    address = input('Address: ')
    print(name.title()), print(address.title())
#function for what type of order. This will run first and send it to the "customer_info" function if delivery
def order_type():
    user_input = input('Delivery, Dine in, or Pick-up: ')
    
    if user_input.lower() == 'delivery':
        customer_info()
    elif user_input.lower() == 'dine in':
        '''Name for the dine in order'''
        name = input('Name: ')
        print(f'{name.title()}\'s pizza for dine in!')
    elif user_input.lower() == 'pick-up':
        '''Name for the pick-up order'''
        name = input('Name: ')
        print(f'{name.title()}\'s pizza for pick-up!')
    else:
        print('Not valid order type!')
        order_type()
order_type()

def get_payment_selection():
    payment_option = int(input('Please select 1 = credit card, 2 = cash, 3 = check '))
    if payment_option == 1:
        print('please input credit card number')
    elif payment_option == 2:
        print('please pay at the store, no bills over $50 accepted')
    elif payment_option == 3:
        print('present second id and no orders under $20 accepted when paying by check')
    else:
        print('please enter a selection from 1-3')
get_payment_selection()

# %%
def pizza_order():
    prices = [8.99, 12.99, 17.99]
    small = prices[0]
    medium = prices[1]
    large = prices[-1]
    pizza = input('Enter your pizza size: ')
    if pizza == 's':
        return small
    elif pizza == 'm':
        return medium
    elif pizza == 'l':
        return large

list_of_toppings = ['extra cheese', 'mushrooms', 'bell peppers', 'red onions', 'italian sausage','pepperoni', 'olives']

def pizza_price_plus_topping_price():
    count = 0
    which_toppings = input('What toppings would you like?: ').lower()
    pizza_size_price = pizza_order()  # replace 12.99 with your fuction here (replaced)
    for topping in which_toppings:
        count += 1
        #Splitting customer's toppings into seperate values and measuring its length of values
        if (count > 2):
            return pizza_size_price + 4
        # Then adding pizza price to topping price
        elif (count == 2):
              return pizza_size_price + 3
        elif (count == 1):
            return pizza_size_price + 1.5
        else:
            return pizza_size_price
pizza_price_plus_topping_price()

# %%
def pizza_order():
    prices = [8.99, 12.99, 17.99]
    small = prices[0]
    medium = prices[1]
    large = prices[-1]
    pizza = input('Enter your pizza size: ')
    if pizza == 's':
        return small
    elif pizza == 'm':
        return medium
    elif pizza == 'l':
        return large

list_of_toppings = ['extra cheese', 'mushrooms', 'bell peppers', 'red onions', 'italian sausage','pepperoni', 'olives']

def pizza_price_plus_topping_price():
    pizza_size_price = pizza_order()  # replace 12.99 with your fuction here (replaced)
    which_toppings = input('What toppings would you like? (seperate each by a comma): ').lower()
    for topping in list_of_toppings:
        #Splitting customer's toppings into seperate values and measuring its length of values
        if len(which_toppings.split(", ")) >= 3:
            return pizza_size_price + 4
        # Then adding pizza price to topping price
        elif len(which_toppings.split(", ")) == 2:
              return pizza_size_price + 3
        elif len(which_toppings.split(", ")) == 1:
            return pizza_size_price + 1.5
        else:
            return pizza_size_price
print(pizza_price_plus_topping_price())
#function for delivery name/address
def customer_info():
    '''Name for the order'''
    name = input('Name: ')
    '''Address to deliver to'''
    address = input('Address: ')
    print(name.title()), print(address.title())
#function for what type of order. This will run first and send it to the "customer_info" function if delivery
def order_type():
    user_input = input('Delivery, Dine in, or Pick-up: ')
    
    if user_input.lower() == 'delivery':
        customer_info()
    elif user_input.lower() == 'dine in':
        '''Name for the dine in order'''
        name = input('Name: ')
        print(f'{name.title()}\'s pizza for dine in!')
    elif user_input.lower() == 'pick-up':
        '''Name for the pick-up order'''
        name = input('Name: ')
        print(f'{name.title()}\'s pizza for pick-up!')
    else:
        print('Not valid order type!')
        order_type()
order_type()

def get_payment_selection():
    '''Takes in an input from the customer and turns that input into an integer'''
    payment_option = int(input('Please select 1 = credit card, 2 = cash, 3 = check '))
    if payment_option == 1:
        str(input('please input credit card number: '))
        print('Thank you for your payment, enjoy your delicious pizza!')
    elif payment_option == 2:
        print('please pay at the store, no bills over $50 accepted')
    elif payment_option == 3:
        print('present second id and no orders under $20 accepted when paying by check')
    else:
        print('please enter a selection from 1-3')
get_payment_selection()
# Out:
# Enter your pizza size: s
# What toppings would you like? (seperate each by a comma): extra cheese, bell peppers
# 11.99
# Delivery, Dine in, or Pick-up: delivery
# Name: Andy
# Address: 1234 Test st
# Andy
# 1234 Test St
# Please select 1 = credit card, 2 = cash, 3 = check 1
# please input credit card number: 8675309999999
# Thank you for your payment, enjoy your delicious pizza!
